# %%
import pandas as pd
import bibtexparser

df_jcs = pd.read_csv("dados/CSV/jcs_2020.csv", sep=';', index_col=['Rank'], )
df_jcs.head()
# Out:
#                          Full Journal Title Total Cites  Unnamed: 3  \
# Rank
# 1        CA-A CANCER JOURNAL FOR CLINICIANS      55,868         NaN
# 2     NATURE REVIEWS MOLECULAR CELL BIOLOGY      58,477         NaN
# 3           NEW ENGLAND JOURNAL OF MEDICINE     464,351         NaN
# 4             NATURE REVIEWS DRUG DISCOVERY      41,989         NaN
# 5                                    LANCET     369,601         NaN
#
#      Journal Impact Factor  Eigenfactor Score  Unnamed: 6  Unnamed: 7
# Rank
# 1                  508.702            0.10514         NaN         NaN
# 2                   94.444            0.07548         NaN         NaN
# 3                   91.245            0.63118         NaN         NaN
# 4                   84.694            0.04822         NaN         NaN
# 5                   79.321            0.44524         NaN         NaN

# %%
# df_jcs.dtypes

# tratamento dos dados
# validando colunas nulas
# df_jcs.info()
print('antes')
df_jcs.isnull().sum()
df_jcs

#eliminar coluna com nulos
df_jcs = df_jcs.dropna(axis=1, how='all')
df_jcs.head()

#uppercase no campo Full Journal Title
df_jcs['Full Journal Title'] = df_jcs['Full Journal Title'].str.upper()

#alterar nome da coluna
df_jcs.rename(columns={'Full Journal Title':'Title'}, inplace=True)
df_jcs.head()
# Out:
# antes
#                                       Title Total Cites Journal Impact Factor  \
# Rank
# 1        CA-A CANCER JOURNAL FOR CLINICIANS      55,868               508.702
# 2     NATURE REVIEWS MOLECULAR CELL BIOLOGY      58,477                94.444
# 3           NEW ENGLAND JOURNAL OF MEDICINE     464,351                91.245
# 4             NATURE REVIEWS DRUG DISCOVERY      41,989                84.694
# 5                                    LANCET     369,601                79.321
#
#       Eigenfactor Score
# Rank
# 1               0.10514
# 2               0.07548
# 3               0.63118
# 4               0.04822
# 5               0.44524

# %%
df_sci = pd.read_csv("dados/CSV/scimagojr 2020.csv" ,sep=';', index_col=['Rank'])
df_sci.head()
# Out:
# /tmp/ipykernel_70046/3857661113.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sci = pd.read_csv("dados/CSV/scimagojr 2020.csv" ,sep=';', index_col=['Rank'])
#          Sourceid                                  Title     Type  \
# Rank
# 1           28773     Ca-A Cancer Journal for Clinicians  journal
# 2           19434       MMWR Recommendations and Reports  journal
# 3           20315  Nature Reviews Molecular Cell Biology  journal
# 4           29431         Quarterly Journal of Economics  journal
# 5     21100812243               Nature Reviews Materials  journal
#
#                     Issn     SJR SJR Best Quartile  H index  \
# Rank
# 1     15424863, 00079235  62,937                Q1      168
# 2     10575987, 15458601  40,949                Q1      143
# 3     14710072, 14710080  37,461                Q1      431
# 4     00335533, 15314650  34,573                Q1      259
# ...

# %%
df_sci.dtypes
# df_sci.info
# df_sci.isnull().sum()
# df_sci
#uppercase no campo Full Journal Title
# df_sci['Title'] = df_sci['Title'].str.upper()
# df_sci.head()
# Out:
# Sourceid                   int64
# Title                     object
# Type                      object
# Issn                      object
# SJR                       object
# SJR Best Quartile         object
# H index                    int64
# Total Docs. (2020)         int64
# Total Docs. (3years)       int64
# Total Refs.                int64
# Total Cites (3years)       int64
# Citable Docs. (3years)     int64
# Cites / Doc. (2years)     object
# Ref. / Doc.               object
# Country                   object
# Region                    object
# Publisher                 object
# Coverage                  object
# Categories                object
# dtype: object

# %%
# merge
df_final = pd.merge(df_sci, df_jcs, on='Title')
# df_final = df_final.query('Title == "ISPRS JOURNAL OF PHOTOGRAMMETRY AND REMOTE SENSING"')

df_final.head()
# Out:
#       Sourceid                                  Title     Type  \
# 0        28773     CA-A CANCER JOURNAL FOR CLINICIANS  journal
# 1        19434       MMWR RECOMMENDATIONS AND REPORTS  journal
# 2        20315  NATURE REVIEWS MOLECULAR CELL BIOLOGY  journal
# 3        29431         QUARTERLY JOURNAL OF ECONOMICS  journal
# 4  21100812243               NATURE REVIEWS MATERIALS  journal
#
#                  Issn     SJR SJR Best Quartile  H index  Total Docs. (2020)  \
# 0  15424863, 00079235  62,937                Q1      168                  47
# 1  10575987, 15458601  40,949                Q1      143                  10
# 2  14710072, 14710080  37,461                Q1      431                 115
# 3  00335533, 15314650  34,573                Q1      259                  40
# 4            20588437  32,011                Q1      108                  92
#
#    Total Docs. (3years)  Total Refs.  ...  Cites / Doc. (2years)  Ref. / Doc.  \
# ...

# %%
# Deduplicacao
print('antes')
print(df_final.shape)

print('depois')
df_final = df_final.drop_duplicates(inplace=False)
print(df_final.shape)
# Out:
# antes
# (10428, 22)
# depois
# (9869, 22)

# %%
# filtros
# df_final = df_final[df_final.Sourceid.eq(29431)]
# df_final = df_final[df_final.Type.eq('journal')]

# df_final = df_final[df_final.Sourceid.isin([29431,20315]) & df_final.Type.eq('journal')]

# query
	
# gapminder.query('country=="United States" & year > 1996')
# df_final = df_final.query('Sourceid in [29431,20315] & Type == "journal" ')

# df_final = df_final.query('Issn == 9781450347792')
df_final = df_final.query('Title == "CA-A CANCER JOURNAL FOR CLINICIANS"')

df_final.head()
# Out:
#    Sourceid                               Title     Type                Issn  \
# 0     28773  CA-A CANCER JOURNAL FOR CLINICIANS  journal  15424863, 00079235
#
#       SJR SJR Best Quartile  H index  Total Docs. (2020)  \
# 0  62,937                Q1      168                  47
#
#    Total Docs. (3years)  Total Refs.  ...  Cites / Doc. (2years)  Ref. / Doc.  \
# 0                   119         3452  ...                 126,34        73,45
#
#          Country            Region        Publisher   Coverage  \
# 0  United States  Northern America  Wiley-Blackwell  1950-2020
#
#                        Categories Total Cites Journal Impact Factor  \
# 0  Hematology (Q1); Oncology (Q1)      55,868               508.702
#
#   Eigenfactor Score
# 0           0.10514
#
# [1 rows x 22 columns]
