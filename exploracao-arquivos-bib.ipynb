# %%
import pandas as pd
import bibtexparser
import yaml
import os
import json

with open('dados/teste/SDC1.bib', encoding='utf8') as bibtex_file:
        bib_database = bibtexparser.load(bibtex_file)
        df = pd.DataFrame(bib_database.entries)

df
# Out:
#                                             abstract  \
# 0  Beyond the hype of Big Data, something within ...
# 1  The recent explosive publications of big data ...
# 2  Background\nActivating prior medical knowledge...
#
#                                             keywords  \
# 0  Data Quality, Big Data, Measurement, Quality-i...
# 1  Big data, Data quality and error, Data ethnics...
# 2  Big data resources, Activation of prior medica...
#
#                                               author  \
# 0  Jorge Merino and Ismael Caballero and Bibiano ...
# 1  Jianzheng Liu and Jie Li and Weifeng Li and Ji...
# 2        Sufen Wang and Junyi Yuan and Changqing Pan
#
#                                                  url  \
# 0  https://www.sciencedirect.com/science/article/...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://www.sciencedirect.com/science/article/...
#
#                                                doi       issn  \
# ...

# %%
# criar campo novo e atribuir valor do journal
df['col_join'] = df['journal']
df['origem'] = 'SDC'
df
# Out:
#                                             abstract  \
# 0  Beyond the hype of Big Data, something within ...
# 1  The recent explosive publications of big data ...
# 2  Background\nActivating prior medical knowledge...
#
#                                             keywords  \
# 0  Data Quality, Big Data, Measurement, Quality-i...
# 1  Big data, Data quality and error, Data ethnics...
# 2  Big data resources, Activation of prior medica...
#
#                                               author  \
# 0  Jorge Merino and Ismael Caballero and Bibiano ...
# 1  Jianzheng Liu and Jie Li and Weifeng Li and Ji...
# 2        Sufen Wang and Junyi Yuan and Changqing Pan
#
#                                                  url  \
# 0  https://www.sciencedirect.com/science/article/...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://www.sciencedirect.com/science/article/...
#
#                                                doi       issn  \
# ...
